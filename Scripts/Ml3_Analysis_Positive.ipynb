# %% [markdown]
# <a href="https://colab.research.google.com/github/kieramurphy37/DS-2002/blob/main/Scripts/Ml3_Analysis_Positive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Import Cleaned Data from GitHub

# %%
url = 'https://raw.githubusercontent.com/Sabrina-Hendricks/DS4002-Group13/main/Data/Cleaned_Data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Review ID  Clothing ID  Age  \
# 0          0          767   33
# 1          1         1080   34
# 2          2         1077   60
# 3          3         1049   50
# 4          4          847   47
#
#                                          Review Text  Sentiment Score  Rating  \
# 0  Absolutely wonderful - silky and sexy and comf...           0.8932       4
# 1  Love this dress!  it's sooo pretty.  i happene...           0.9729       5
# 2  I had such high hopes for this dress and reall...           0.9208       3
# 3  I love, love, love this jumpsuit. it's fun, fl...           0.5727       5
# 4  This shirt is very flattering to all due to th...           0.9291       5
#
#    Recommended IND  Positive Feedback Count   Division Name Department Name  \
# 0                1                        0       Initmates        Intimate
# 1                1                        4         General         Dresses
# 2                0                        0         General         Dresses
# 3                1                        0  General Petite         Bottoms
# 4                1                        6         General            Tops
#
#    ... Class Name_Skirts  Class Name_Sleep Class Name_Sweaters  \
# 0  ...             False             False               False
# 1  ...             False             False               False
# 2  ...             False             False               False
# 3  ...             False             False               False
# 4  ...             False             False               False
#
#    Class Name_Swim  Class Name_Trend  Age Group_25-34  Age Group_35-44  \
# 0            False             False             True            False
# 1            False             False             True            False
# 2            False             False            False            False
# 3            False             False            False            False
# 4            False             False            False            False
#
#    Age Group_45-54  Age Group_55-64  Age Group_65+
# 0            False            False          False
# 1            False            False          False
# 2            False             True          False
# 3             True            False          False
# 4             True            False          False
#
# [5 rows x 44 columns]

# %%
sns.histplot(df['Sentiment Score'], bins=15, kde=True)
# Out:
# <Axes: xlabel='Sentiment Score', ylabel='Count'>

# %%
sns.barplot(data=df, x='Sentiment Score', hue='Age Group')
# Out:
# <Axes: xlabel='Sentiment Score'>

# %% [markdown]
# Defining Simple Linear Regression Function

# %%
np.random.seed(102) # Set the seed for the random number generator
N = 30

x = 5 + 2*np.random.normal(0,1,size = N) # Create an x
eps = np.random.normal(0,3,size = N) # Create noise
b0 = -1 # Intercept coefficoent
b1 = 3 # Slope coefficient
y = b0 + b1*x + eps

def slr(x,y): # Single Linear Regression Function
    x_bar = np.mean(x)
    y_bar = np.mean(y)
    b1 = np.inner(x-x_bar,y-y_bar)/np.inner(x-x_bar,x)
    b0 = y_bar - b1*x_bar
    y_hat = b0 + b1*x
    residuals = y - y_hat
    return({'b0':b0,'b1':b1,'y_hat':y_hat,'residuals':residuals})

# %% [markdown]
# Regress Sentiment Score on Age

# %%
x = df['Age']
y = df['Sentiment Score']

coef = slr(x,y) # Single Linear Regression
print('Intercept: ',coef['b0'], '\n', ' Slope: ', coef['b1'])

y_hat = coef['b0']+coef['b1']*x # Compute predictions

# Scatter plot of fit:
plt.scatter(x,y,label='Data')
plt.plot(x,y_hat,label='Regression Line',color='black')
plt.xlabel("Age")
plt.ylabel("Sentiment Score")
plt.legend(loc='upper right')
plt.title('Linear Regression')

plt.show()
# Out:
# Intercept:  0.7433385107894891
#   Slope:  -6.515519335163639e-05

# %% [markdown]
# Box plot of Sentiment Score, grouped by Age Group

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="Age Group", y='Sentiment Score', data=df)

plt.xlabel('Age Group')
plt.ylabel('Sentiment Score')
plt.title('Boxplot of Sentiment Scores by Age Group')

plt.show()

# %%
positive_df = df[df['Sentiment Score'] > 0.5]

positive_df.head()
# Out:
#    Review ID  Clothing ID  Age  \
# 0          0          767   33
# 1          1         1080   34
# 2          2         1077   60
# 3          3         1049   50
# 4          4          847   47
#
#                                          Review Text  Sentiment Score  Rating  \
# 0  Absolutely wonderful - silky and sexy and comf...           0.8932       4
# 1  Love this dress!  it's sooo pretty.  i happene...           0.9729       5
# 2  I had such high hopes for this dress and reall...           0.9208       3
# 3  I love, love, love this jumpsuit. it's fun, fl...           0.5727       5
# 4  This shirt is very flattering to all due to th...           0.9291       5
#
#    Recommended IND  Positive Feedback Count   Division Name Department Name  \
# 0                1                        0       Initmates        Intimate
# 1                1                        4         General         Dresses
# 2                0                        0         General         Dresses
# 3                1                        0  General Petite         Bottoms
# 4                1                        6         General            Tops
#
#    ... Class Name_Skirts  Class Name_Sleep Class Name_Sweaters  \
# 0  ...             False             False               False
# 1  ...             False             False               False
# 2  ...             False             False               False
# 3  ...             False             False               False
# 4  ...             False             False               False
#
#    Class Name_Swim  Class Name_Trend  Age Group_25-34  Age Group_35-44  \
# 0            False             False             True            False
# 1            False             False             True            False
# 2            False             False            False            False
# 3            False             False            False            False
# 4            False             False            False            False
#
#    Age Group_45-54  Age Group_55-64  Age Group_65+
# 0            False            False          False
# 1            False            False          False
# 2            False             True          False
# 3             True            False          False
# 4             True            False          False
#
# [5 rows x 44 columns]

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="Age Group", y='Sentiment Score', data=positive_df)

plt.xlabel('Age Group')
plt.ylabel('Sentiment Score')
plt.title('Boxplot of Sentiment Scores by Age Group')

plt.show()

# %%
x = positive_df['Age']
y = positive_df['Sentiment Score']

coef = slr(x,y) # Single Linear Regression
print('Intercept: ',coef['b0'], '\n', ' Slope: ', coef['b1'])

y_hat = coef['b0']+coef['b1']*x # Compute predictions

# Scatter plot of fit:
plt.scatter(x,y,label='Data')
plt.plot(x,y_hat,label='Regression Line',color='black')
plt.xlabel("Age")
plt.ylabel("Sentiment Score")
plt.legend(loc='upper right')
plt.title('Linear Regression')

plt.show()
# Out:
# Intercept:  0.8739482721993942
#   Slope:  -1.5912771919693404e-05
